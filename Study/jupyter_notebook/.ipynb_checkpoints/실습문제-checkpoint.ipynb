# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#
x = 1 
y = 2
print(x, y)

tmp = x
x = y 
y = tmp
print(x, y)
# Out:
# 1 2
# 2 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x, y = 10, 20

x, y = y, x

print(x, y)
# Out:
# 20 10

# %% [markdown]
# 식별자
#
# 영문 알파벳(대문자와 소문자), 언더스코어(_), 숫자로 구성됩니다.
# 첫 글자에 숫자가 올 수 없습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#
boxes = ['A', 'B', ['apple', 'banana', 'cherry']]
#
boxes[2][-1]
#
boxes[-1][1][0]
# Out:
# 'b'

# %%
# 하나의 항목으로 구성된 튜플은 생성 시 값 뒤에 쉼표를 붙여야 합니다.
# 아래 코드를 실행하여 변수 a의 타입을 확인해 봅시다.
a = 1,
print(a)
print(type(a))
# Out:
# (1,)
# <class 'tuple'>

# %%
b = 1, 2, 3
print(b)
print(type(b))
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
d= 1
d2= 3
print(d, ':' ,d2)
print('{'+f'\n\t{d}ㅇㅇ'+'}')
# Out:
# 1 : 3
# {
# 	1ㅇㅇ}

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n-1)
factorial(4)
# Out:
# 24

# %%
ord()
chr()
