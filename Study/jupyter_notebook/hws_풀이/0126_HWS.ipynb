# %% [markdown]
# # Python 07. 객체 지향 프로그래밍 (HW)

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %%
print(type([1,2,3]))
print(type('sss'))
print(type((3,4)))
print(type(True))
print(type(1))
# Out:
# <class 'list'>
# <class 'str'>
# <class 'tuple'>
# <class 'bool'>
# <class 'int'>

# %% [markdown]
# int, str, tuple, bool, list, float, dict

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# * `--init__` : 생성자 메소드, 데이터를 초기화 하는 등의 목적으로 사용됨
#
#
# * `__del__` : 객체가 소멸될 때 호출됨
#
#
# * `__str__` : 해당 객체의 출력 형태를 지정, 프린트 함수를 호출할 때 자동 호출
#
#
# * `__repr__` : 출력 형태를 지정, 반환값을 eval함수에 사용할 수 있음(representation의 약자; 표현하다)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 1. `append( ) 메서드로 기존 리스트에 특정 데이터를 추가` : append( ) 메서드로 기존 리스트에 특정 데이터를 추가
#
# 2. `리스트명.index('위치를 찾을 데이터명')` : insert( ) 메서드로 리스트에서 선택한 위치에 특정 데이터를 추가
#
# 3. `리스트명.count('개수를 셀 데이터명')` : count( ) 메서드는 리스트에서 괄호 안의 인자와 일치하는 데이터의 개수를 셈
#
# upper,lower,
#
# dic : .items() .get() .update()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (a) fibo (b) fibo_recrusion (c) recursion

# %% [markdown]
# ---

# %% [markdown]
# # Python 07. 객체 지향 프로그래밍 (WS)

# %% [markdown]
# Faker는 개발시 활용할 수 있는 가상의 데이터를 생성해주는 파이썬 패키지이다.
# 워크샵에 등장하는 코드는 모두 Github(https://github.com/joke2k/faker) 문서의 예제이다.
# 지금까지 배운 파이썬 개념을 활용하여 해석 하시오.
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# (1) 개발시 활용할 수 있는 가상의 데이터를 생성해주는 faker라는 패키지를 설치하기 위한 명령어
# (2) python이 설치된 후 git bash 환경 등에서 실행함.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 1 faker 패키지에서 Faker 클래스 가지고 오기
# 2 Faker는 클래스, fake는 인스턴스
# 3 메서드

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# (a) init, (b) self, (c) locale = 'en_US'

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
pip install Faker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker


import random

# random.random() # => 임의의 수
# random.random() # => 임의의 수

# random.seed(7777)
# random.random() # =>

# random.seed(7777)
# random.random() # =>

fake = Faker('ko_KR')
Faker.seed(4321)

print(fake.name())

fake2 = Faker('ko_KR')
print(fake2.name())

#########################

fake = Faker('ko_KR')
fake.seed_instance(4321)

print(fake.name())

fake2 = Faker('ko_KR')
print(fake2.name())
# Out:
# 이도윤
# 이지후
# 이도윤
# 김광수

# %% [markdown]
# 1. `#1 출력결과` : 이도윤
# 2. `#2 출력결과` : 이지후
#
# 임의로 어떤 값을 하나 만들었는데 그 값을 계속 사용하고 싶을 때 사용하는것이 seeding
# seed() 는 클래스 메서드

# %% [markdown]
# 1. `#1 출력결과` : 이도윤
#
# 2. `#2 출력결과` : 김광수
# 3. 인스턴스 메서드
# 4. 1. seed()의 용도는 클래스 내의 모든 인스턴스에 사용되고 , seed_instance()의 용도는 특정한 인스턴스에서만 사용된다.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
