# %% [markdown]
# # Web 03. HTML & CSS (HW)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-9.png](attachment:image-9.png)
#
# https://getbootstrap.kr/docs/5.1/getting-started/introduction/

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# btn btn-success

# %% [markdown]
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# a) dark
#
# b) navbarSupportedContent
#
# c) navbar-nav

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a) pagination
#
# b) disabled
#
# c) active

# %% [markdown]
# ---

# %% [markdown]
# # Web 03. HTML & CSS (WS)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# li태그니까 부모인 ul태그에 d-flex를 주면 됨

# %% [markdown]
# 2rem은어떻게하지?
# ![image.png](attachment:image.png)
# li에 class="mx-3"을 넣으면 됨

# %% [markdown]
# 밑줄 지우려면 어떻게 하지?? text decoreation

# %% [markdown]
# ![image.png](attachment:image.png)
# 이 안에서
#
# article안에서 좌우방향으로 배치
# ![image-2.png](attachment:image-2.png)
#
#
# 부모에 d-flex
# justify-content / align-items-center
#
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)
