# %% [markdown]
# # Web 01. HTML & CSS (HW)

# %% [markdown]
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# (3)

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# 1) F
# 2) F
# 3) F
# 4) F
# 5) F

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# (2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
1) T
2) T
3) F
4) T
5) T

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# !important, Inline style, id 선택자, class 선택자, 요소 선택자, 소스 순서

# %% [markdown]
# ---

# %% [markdown]
# # Web 01. HTML & CSS (WS)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <img src="C:\Users\Windows 10\Desktop\TIL\ssafy\image" alt="ssafy">

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a) 상대경로
# b) 절대경로
# b로 변경한 코드) C:\Users\Windows 10\Desktop\TIL\ssafy\image
