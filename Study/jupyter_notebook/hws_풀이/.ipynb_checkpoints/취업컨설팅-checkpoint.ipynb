# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# 개인의 흥미특성을 6개로,
#
# 사회적바람직성이 높다면 보이는거에 중시
# 부주의성이 높다면 대충 찍음
#
# ![image.png](attachment:image.png)

# %%
[서울_4반_문숙경_EC]
