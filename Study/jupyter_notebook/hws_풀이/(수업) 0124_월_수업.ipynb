# %% [markdown]
# # 문자열 메소드

# %% [markdown]
# * is가 들어가 있으면 결과가 boolean이다.

# %% [markdown]
# ## 없으면 -1(기본값)을 반환 or 없으면 오류 발생
# 비슷한 동작이지만 결과가 다른 것들이 있음
# 함정 문제!!

# %% [markdown]
# ### 조회 탐색 메서드
# s.find(x) : x의 첫 번 째 위치를 반환, 없으면 -1 반환
# s.index(x) : x의 첫 번 째 위치를 반환, 없으면 오류 발생
#
# ### 검증 관련 메서드
# s.isalpha() : 알파벳여부
# s.isupper()
# s.islower()
# s.istitle() # 얘가 핵심?!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# numeric이 더 상위개념이라고만 알면 됨

# %% [markdown]
# # 문자열 변경 메소드

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# join 메소드

# print(       ,end=' ') = ' '.join(['3', '5'])

# %% [markdown]
# # 실수 많이 하는 부분

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * remove() : 있는 애를 찾으면 제거
# * pop() : 오른쪽에 있는 항목을 반환 후 제거

# %% [markdown]
# ![image.png](attachment:image.png)
