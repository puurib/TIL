# %% [markdown]
# # 알고리즘 주간 문제 총정리

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
T = 6

for tc in range(1, T+1):
    n = list(map(int, input().split()))

for i in range(len(n)):
    print(n[i], end=' ')
# Out:
# 3
# 1 2 3 4 5
# 3
# 1 2 3
# 4 5 6
# 7 8 9
# 7 8 9
