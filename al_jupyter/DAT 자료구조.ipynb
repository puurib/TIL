# %% [markdown]
# # DAT (direct address table 자료구조)
#
# * 빠른 검색을 위한 자료구조
# * count sort 기본원리

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. 버킷을 등록한다 = 0 * 9 개 (b의 개수 혹은 더 많이)
#
# 2. for 문을 이용해서 a문(a의길이만큼) 을 돌면서 O, X,
#    flag = 1을 넣거나,
#    +1을 한다.
#
# 3.

# %%
# 카운팅 정렬 기초

a = [4, 9, 1, 4, 4, 2]
b = [1, 3, 4, 2, 5, 6, 7, 8, 9]

bucket = [0] * 10

# bucket에 값 넣기
for i in range(len(a)):
    index = a[i]
    bucket[index] += 1
print(bucket)
# bucket 누적합
for i in range(1, len(bucket)):
    bucket[i] += bucket[i-1]

print(bucket)
# Out:
# [0, 1, 1, 0, 3, 0, 0, 0, 0, 1]
# [0, 1, 2, 2, 5, 5, 5, 5, 5, 6]

# %%
a = [4, 7, 9, 1, 3, 5, 2, 4, 2]

# dat 등록
bucket = [0] * 10
rlt = [0] * 10

# 누적합
for i in range(len(a)):
    bucket[a[i]] += 1

    
# 값 넣기
for i in range(1, len(bucket)):
    bucket[i] += bucket[i -1]
    
# print(bucket)
for i in range()
# Out:
# [0, 1, 3, 4, 6, 7, 7, 8, 8, 9]
