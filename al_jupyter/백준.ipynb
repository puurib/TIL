# %% [markdown]
# ![image.png](attachment:image.png)

# %%
numbers = list(map(int, input().split()))

for i in range(len(numbers)):
    for j in range(i):
        if numbers[i] < numbers[j]:
            numbers[i], numbers[j] = numbers[j], numbers[i]


print(numbers[1]) # 세 수 중에 두 번째로 큰 수를 구함
