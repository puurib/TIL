# %% [markdown]
# # 알고리즘 1일차 ~ 8일차 (02/09 ~ 02/18)
#
# ## 기본 문제 (심화 제외) : 38문제
#
#
# 1. 02/09 List I 5문제 : 입력받기, 이차원배열다루기, Gravity, Babygin, SWEA-1206(View)
#
#
# 2. 02/10 List I 5문제 : 4828_min_max, 4831_electric_bus, 4834_cards, 4835_sumofintervals, 1208_flatten
#
#
# 3. 02/14 List II 4문제 : 구간의 절대값, 부분집합의 합, 1954_snail, 1209_sum
#
#
# 4. 02/15 List II 5문제 : 4836_색칠하기, 4837_부분집합의합, 4839_이진탐색, 4843_특별한탐색, 1210_ladder1
#
#
# 5. 02/16 String 4문제 : 연습문제1 문자열 뒤집기, 연습문제2 정수를 문자열로 반환, 연습문제3 String, SWEA-GNS
#
#
# 6. 02/17 String 5문제 : 4864_문자열비교, 4861_회문, 4865_글자수, 3143_가장빠른문자열타이핑, 1216_회문2
#
#
# 7. 02/18 라이브 10문제 : 2001_파리퇴치(필수), 1974_스도쿠 검증(필수)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4828. [파이썬 S/W 문제해결 기본] 1일차 - min max
#
#
# ! 이문제가 요구하는 것은,
# - min_val, max_val를 전역에 초기화해두고, 값을 변화시킬 수 있느냐가 포인트다.
# - 모든 문제에서 쓰이는 최대, 최소값이므로 모르면 진짜 뒤져..

# %% [markdown]
# ![image.png](attachment:image.png)
