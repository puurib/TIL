# %% [markdown]
# # 문제 1번
#
# ![image.png](attachment:image.png)

# %%
arr = [3, 4, 1, 1, 2] 

idx = int(input())-1

for i in range(-idx, 4):
    print(arr[i], end=' ')
# Out:
# 2
# 2 3 4 1 1

# %% [markdown]
# # 문제 2번

# %% [markdown]
# ![image.png](attachment:image.png)
