# %% [markdown]
# # 파리퇴치
# ![image.png](attachment:image.png)

# %% [markdown]
# # 스도쿠 검증

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 아스키 코드

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(chr(ord('A') + (100 % 26)))
# Out:
# W

# %% [markdown]
# # GNS

# %% [markdown]
# ![image.png](attachment:image.png)
