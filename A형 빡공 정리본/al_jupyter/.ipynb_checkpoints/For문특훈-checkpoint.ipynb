# %% [markdown]
# # 문제 1번
#
# ![image.png](attachment:image.png)

# %%
arr = [3, 4, 1, 1, 2]
n = int(input()) - 1

new = [0] * 5
for i in range(len(arr)):
    if i != len(arr)-1:
        new[n + 1] = arr[n]
print(new)
# Out:
# 2
# [0, 0, 4, 0, 0]
